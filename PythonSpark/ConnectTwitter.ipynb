# %%
import twitter
import urlparse
from pprint import pprint as pp

# %%
class TwitterAPI(object):
#"""
#TwitterAPI class allows the Connection to Twitter via OAuth
#once you have registered with Twitter and receive the
#necessary credentiials
#"""
# initialize and get the twitter credentials
    def __init__(self):
        consumer_key = '7cafpvyNC3G5jBy7mA27bx9Oo'
        consumer_secret = 'BnomaQh2WNblSaRrfmWZuKaWy60KOYqIr9Jy1gomFEWJWz1vr7'
        access_token = '97539286-QWma2TH9cCBSLItuavZeoo11GCsiaDp7Lm9dpxrrE'
        access_secret = 'sEcvyLDjlHpUmng7wo05iWAFXuLu29WXmPFXY5k7IZ0SN'
        self.consumer_key = consumer_key
        self.consumer_secret = consumer_secret
        self.access_token = access_token
        self.access_secret = access_secret
        
        # authenticate credentials with Twitter using OAuth
        self.auth = twitter.oauth.OAuth(access_token, access_secret,consumer_key, consumer_secret)
        self.api = twitter.Twitter(auth=self.auth)
        
# search Twitter with query q (i.e. "ApacheSpark") and max. result
    def searchTwitter(self, q, max_res=10,**kwargs):
        search_results = self.api.search.tweets(q=q, count=10, **kwargs)
        statuses = search_results['statuses']
        max_results = min(1000, max_res)
        
        for _ in range(10):
            try:
                next_results = search_results['search_metadata']['next_results']
            except KeyError as e:
                break
            next_results = urlparse.parse_qsl(next_results[1:])
            kwargs = dict(next_results)
            search_results = self.api.search.tweets(**kwargs)
            statuses += search_results['statuses']
            if len(statuses) > max_results:
                break
        return statuses
    
    # parse tweets as it is collected to extract id, creation
    # date, user id, tweet text
    def parseTweets(self, statuses):
        return [ (status['id'],status['created_at'],status['user']['id'],
            status['user']['name'],status['text'], url['expanded_url'])
            for status in statuses
                for url in status['entities']['urls'] ]

# %%
t= TwitterAPI()

# %%
#run search with term "ApacheSpark"
query = "ApacheSpark"
tsearch = t.searchTwitter(query)

# %%
#view json file
pp(tsearch[1])
# Out:
# {u'contributors': None,
#  u'coordinates': None,
#  u'created_at': u'Sat Dec 26 15:37:15 +0000 2015',
#  u'entities': {u'hashtags': [],
#                u'media': [{u'display_url': u'pic.twitter.com/m35H7GltMV',
#                            u'expanded_url': u'http://twitter.com/bigdata/status/680765268876902401/photo/1',
#                            u'id': 680490092620730369,
#                            u'id_str': u'680490092620730369',
#                            u'indices': [139, 140],
#                            u'media_url': u'http://pbs.twimg.com/media/CXGWIkPU0AEGtjZ.jpg',
#                            u'media_url_https': u'https://pbs.twimg.com/media/CXGWIkPU0AEGtjZ.jpg',
#                            u'sizes': {u'large': {u'h': 678,
#                                                  u'resize': u'fit',
#                                                  u'w': 1024},
#                                       u'medium': {u'h': 397,
#                                                   u'resize': u'fit',
#                                                   u'w': 600},
#                                       u'small': {u'h': 225,
#                                                  u'resize': u'fit',
#                                                  u'w': 340},
#                                       u'thumb': {u'h': 150,
#                                                  u'resize': u'crop',
#                                                  u'w': 150}},
#                            u'source_status_id': 680765268876902401,
#                            u'source_status_id_str': u'680765268876902401',
#                            u'source_user_id': 18318677,
#                            u'source_user_id_str': u'18318677',
#                            u'type': u'photo',
#                            u'url': u'https://t.co/m35H7GltMV'}],
#                u'symbols': [],
#                u'urls': [{u'display_url': u'goo.gl/cSnyKq',
#                           u'expanded_url': u'https://goo.gl/cSnyKq',
#                           u'indices': [104, 127],
#                           u'url': u'https://t.co/9KyJDv6oZJ'}],
#                u'user_mentions': [{u'id': 18318677,
#                                    u'id_str': u'18318677',
#                                    u'indices': [3, 11],
#                                    u'name': u'Ben Lorica',
#                                    u'screen_name': u'bigdata'},
#                                   {u'id': 1551361069,
#                                    u'id_str': u'1551361069',
#                                    u'indices': [52, 64],
#                                    u'name': u'Apache Spark',
#                                    u'screen_name': u'ApacheSpark'},
#                                   {u'id': 824776921,
#                                    u'id_str': u'824776921',
#                                    u'indices': [93, 103],
#                                    u'name': u'Evan Chan',
#                                    u'screen_name': u'Evanfchan'}]},
#  u'favorite_count': 0,
#  u'favorited': False,
#  u'geo': None,
#  u'id': 680774380503318528,
#  u'id_str': u'680774380503318528',
#  u'in_reply_to_screen_name': None,
#  u'in_reply_to_status_id': None,
#  u'in_reply_to_status_id_str': None,
#  u'in_reply_to_user_id': None,
#  u'in_reply_to_user_id_str': None,
#  u'is_quote_status': False,
#  u'lang': u'en',
#  u'metadata': {u'iso_language_code': u'en', u'result_type': u'recent'},
#  u'place': None,
#  u'possibly_sensitive': False,
#  u'retweet_count': 5,
#  u'retweeted': False,
#  u'retweeted_status': {u'contributors': None,
#                        u'coordinates': None,
#                        u'created_at': u'Sat Dec 26 15:01:02 +0000 2015',
#                        u'entities': {u'hashtags': [],
#                                      u'media': [{u'display_url': u'pic.twitter.com/m35H7GltMV',
#                                                  u'expanded_url': u'http://twitter.com/bigdata/status/680765268876902401/photo/1',
#                                                  u'id': 680490092620730369,
#                                                  u'id_str': u'680490092620730369',
#                                                  u'indices': [115, 138],
#                                                  u'media_url': u'http://pbs.twimg.com/media/CXGWIkPU0AEGtjZ.jpg',
#                                                  u'media_url_https': u'https://pbs.twimg.com/media/CXGWIkPU0AEGtjZ.jpg',
#                                                  u'sizes': {u'large': {u'h': 678,
#                                                                        u'resize': u'fit',
#                                                                        u'w': 1024},
#                                                             u'medium': {u'h': 397,
#                                                                         u'resize': u'fit',
#                                                                         u'w': 600},
#                                                             u'small': {u'h': 225,
#                                                                        u'resize': u'fit',
#                                                                        u'w': 340},
#                                                             u'thumb': {u'h': 150,
#                                                                        u'resize': u'crop',
#                                                                        u'w': 150}},
#                                                  u'type': u'photo',
#                                                  u'url': u'https://t.co/m35H7GltMV'}],
#                                      u'symbols': [],
#                                      u'urls': [{u'display_url': u'goo.gl/cSnyKq',
#                                                 u'expanded_url': u'https://goo.gl/cSnyKq',
#                                                 u'indices': [91, 114],
#                                                 u'url': u'https://t.co/9KyJDv6oZJ'}],
#                                      u'user_mentions': [{u'id': 1551361069,
#                                                          u'id_str': u'1551361069',
#                                                          u'indices': [39,
#                                                                       51],
#                                                          u'name': u'Apache Spark',
#                                                          u'screen_name': u'ApacheSpark'},
#                                                         {u'id': 824776921,
#                                                          u'id_str': u'824776921',
#                                                          u'indices': [80,
#                                                                       90],
#                                                          u'name': u'Evan Chan',
#                                                          u'screen_name': u'Evanfchan'}]},
#                        u'favorite_count': 4,
#                        u'favorited': False,
#                        u'geo': None,
#                        u'id': 680765268876902401,
#                        u'id_str': u'680765268876902401',
#                        u'in_reply_to_screen_name': None,
#                        u'in_reply_to_status_id': None,
#                        u'in_reply_to_status_id_str': None,
#                        u'in_reply_to_user_id': None,
#                        u'in_reply_to_user_id_str': None,
#                        u'is_quote_status': False,
#                        u'lang': u'en',
#                        u'metadata': {u'iso_language_code': u'en',
#                                      u'result_type': u'recent'},
#                        u'place': None,
#                        u'possibly_sensitive': False,
#                        u'retweet_count': 5,
#                        u'retweeted': False,
#                        u'source': u'<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
#                        u'text': u'FiloDB, from one of the early users of @ApacheSpark + Cassandra: conversation w @Evanfchan https://t.co/9KyJDv6oZJ https://t.co/m35H7GltMV',
#                        u'truncated': False,
#                        u'user': {u'contributors_enabled': False,
#                                  u'created_at': u'Mon Dec 22 22:06:18 +0000 2008',
#                                  u'default_profile': False,
#                                  u'default_profile_image': False,
#                                  u'description': u'Chief Data Scientist @OReillyMedia. Director of Content Strategy @strataconf. Aspirant Parisien. Every Sunday is a Hack Day.',
#                                  u'entities': {u'description': {u'urls': []},
#                                                u'url': {u'urls': [{u'display_url': u'gradientflow.com',
#                                                                    u'expanded_url': u'http://gradientflow.com/',
#                                                                    u'indices': [0,
#                                                                                 22],
#                                                                    u'url': u'http://t.co/XQGNosq847'}]}},
#                                  u'favourites_count': 41,
#                                  u'follow_request_sent': False,
#                                  u'followers_count': 29446,
#                                  u'following': False,
#                                  u'friends_count': 230,
#                                  u'geo_enabled': False,
#                                  u'has_extended_profile': False,
#                                  u'id': 18318677,
#                                  u'id_str': u'18318677',
#                                  u'is_translation_enabled': False,
#                                  u'is_translator': False,
#                                  u'lang': u'en',
#                                  u'listed_count': 1975,
#                                  u'location': u'San Francisco, CA',
#                                  u'name': u'Ben Lorica',
#                                  u'notifications': False,
#                                  u'profile_background_color': u'C6E2EE',
#                                  u'profile_background_image_url': u'http://abs.twimg.com/images/themes/theme2/bg.gif',
#                                  u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme2/bg.gif',
#                                  u'profile_background_tile': False,
#                                  u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/18318677/1441476788',
#                                  u'profile_image_url': u'http://pbs.twimg.com/profile_images/235298259/bigdata_logo_center3_normal.jpg',
#                                  u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/235298259/bigdata_logo_center3_normal.jpg',
#                                  u'profile_link_color': u'1F98C7',
#                                  u'profile_sidebar_border_color': u'C6E2EE',
#                                  u'profile_sidebar_fill_color': u'DAECF4',
#                                  u'profile_text_color': u'663B12',
#                                  u'profile_use_background_image': True,
#                                  u'protected': False,
#                                  u'screen_name': u'bigdata',
#                                  u'statuses_count': 4791,
#                                  u'time_zone': u'Alaska',
#                                  u'url': u'http://t.co/XQGNosq847',
#                                  u'utc_offset': -32400,
#                                  u'verified': False}},
#  u'source': u'<a href="https://roundteam.co" rel="nofollow">RoundTeam</a>',
#  u'text': u'RT @bigdata: FiloDB, from one of the early users of @ApacheSpark + Cassandra: conversation w @Evanfchan https://t.co/9KyJDv6oZJ https://t.c\u2026',
#  u'truncated': False,
#  u'user': {u'contributors_enabled': False,
#            u'created_at': u'Sun Oct 25 03:31:28 +0000 2009',
#            u'default_profile': False,
#            u'default_profile_image': False,
#            u'description': u'Gathering #data intelligence posts from Twitter and other channels to augment old media reporting with # media.',
#            u'entities': {u'description': {u'urls': []},
#                          u'url': {u'urls': [{u'display_url': u'twitter.com/thugmetrics',
#                                              u'expanded_url': u'http://twitter.com/thugmetrics',
#                                              u'indices': [0, 22],
#                                              u'url': u'http://t.co/nK5Zryaxoi'}]}},
#            u'favourites_count': 0,
#            u'follow_request_sent': False,
#            u'followers_count': 12779,
#            u'following': False,
#            u'friends_count': 11309,
#            u'geo_enabled': False,
#            u'has_extended_profile': False,
#            u'id': 85001062,
#            u'id_str': u'85001062',
#            u'is_translation_enabled': False,
#            u'is_translator': False,
#            u'lang': u'en',
#            u'listed_count': 2864,
#            u'location': u'USA',
#            u'name': u'Thug Metrics News',
#            u'notifications': False,
#            u'profile_background_color': u'131516',
#            u'profile_background_image_url': u'http://pbs.twimg.com/profile_background_images/555479473835872256/i85xxy7K.jpeg',
#            u'profile_background_image_url_https': u'https://pbs.twimg.com/profile_background_images/555479473835872256/i85xxy7K.jpeg',
#            u'profile_background_tile': True,
#            u'profile_image_url': u'http://pbs.twimg.com/profile_images/555474607101071360/jy1EJZCF_normal.jpeg',
#            u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/555474607101071360/jy1EJZCF_normal.jpeg',
#            u'profile_link_color': u'ABB8C2',
#            u'profile_sidebar_border_color': u'EEEEEE',
#            u'profile_sidebar_fill_color': u'EFEFEF',
#            u'profile_text_color': u'333333',
#            u'profile_use_background_image': True,
#            u'protected': False,
#            u'screen_name': u'ThugMetricsNews',
#            u'statuses_count': 102527,
#            u'time_zone': u'Central Time (US & Canada)',
#            u'url': u'http://t.co/nK5Zryaxoi',
#            u'utc_offset': -21600,
#            u'verified': False}}

# %%
#parse the twitter output
tparsed = t.parseTweets(tsearch)
pp(tparsed)
# Out:
# [(680778003081641986,
#   u'Sat Dec 26 15:51:38 +0000 2015',
#   14183440,
#   u'Suminda Dharmasena',
#   u'RT @dsetrakyan: Yahoo benchmarks @ApacheFlink, @ApacheSpark and @ApacheStorm https://t.co/MV5MqGPWD6',
#   u'http://www.infoq.com/news/2015/12/yahoo-flink-spark-storm#.Vn2euwMPrnw.twitter'),
#  (680774380503318528,
#   u'Sat Dec 26 15:37:15 +0000 2015',
#   85001062,
#   u'Thug Metrics News',
#   u'RT @bigdata: FiloDB, from one of the early users of @ApacheSpark + Cassandra: conversation w @Evanfchan https://t.co/9KyJDv6oZJ https://t.c\u2026',
#   u'https://goo.gl/cSnyKq'),
#  (680774135874719744,
#   u'Sat Dec 26 15:36:16 +0000 2015',
#   18160154,
#   u'Jonas Bon\xe9r',
#   u'RT @bigdata: FiloDB, from one of the early users of @ApacheSpark + Cassandra: conversation w @Evanfchan https://t.co/9KyJDv6oZJ https://t.c\u2026',
#   u'https://goo.gl/cSnyKq'),
#  (680768927664893952,
#   u'Sat Dec 26 15:15:35 +0000 2015',
#   989845394,
#   u'BigDataBuzz',
#   u'RT @bigdata: FiloDB, from one of the early users of @ApacheSpark + Cassandra: conversation w @Evanfchan https://t.co/9KyJDv6oZJ https://t.c\u2026',
#   u'https://goo.gl/cSnyKq'),
#  (680768093027602432,
#   u'Sat Dec 26 15:12:16 +0000 2015',
#   147907835,
#   u'Bikash Kumar Patra',
#   u'RT @bigdata: FiloDB, from one of the early users of @ApacheSpark + Cassandra: conversation w @Evanfchan https://t.co/9KyJDv6oZJ https://t.c\u2026',
#   u'https://goo.gl/cSnyKq'),
#  (680767263167922177,
#   u'Sat Dec 26 15:08:58 +0000 2015',
#   243346427,
#   u'Christy Wilson',
#   u'RT @Syncsort: Which #Hadoop Option Should You Use? https://t.co/tZkjCEmw6S #apachespark #ApacheFlink #Apachestorm @christylwilson https://t\u2026',
#   u'http://sync.st/1JrAW9I'),
#  (680766572521242624,
#   u'Sat Dec 26 15:06:13 +0000 2015',
#   2997608763,
#   u'Emma Clark',
#   u'RT @bigdata: FiloDB, from one of the early users of @ApacheSpark + Cassandra: conversation w @Evanfchan https://t.co/9KyJDv6oZJ https://t.c\u2026',
#   u'https://goo.gl/cSnyKq'),
#  (680765268876902401,
#   u'Sat Dec 26 15:01:02 +0000 2015',
#   18318677,
#   u'Ben Lorica',
#   u'FiloDB, from one of the early users of @ApacheSpark + Cassandra: conversation w @Evanfchan https://t.co/9KyJDv6oZJ https://t.co/m35H7GltMV',
#   u'https://goo.gl/cSnyKq'),
#  (680749972875276289,
#   u'Sat Dec 26 14:00:15 +0000 2015',
#   2424736675,
#   u'Chris Matthew',
#   u'RT @IBMbigdata: Want to create super smart weather apps that harness the power of #ApacheSpark? #Sparkathon https://t.co/48DaVBRzWl https:/\u2026',
#   u'http://ibm.co/1ltxiGK'),
#  (680736047748104194,
#   u'Sat Dec 26 13:04:55 +0000 2015',
#   2415754303,
#   u'EasyLearning.Guru',
#   u"Blog on #ApacheSpark #Scala and it's Comparison with other Programming Language. Go through the Link: https://t.co/dlnmEtl6qy",
#   u'http://goo.gl/RQWom1'),
#  (680730113726636032,
#   u'Sat Dec 26 12:41:21 +0000 2015',
#   75940765,
#   u'Cesar A. Nogueira',
#   u"RT @ThoHeller: Natural Born Developer's Daily on #Containers, #Docker, #BigData, #ApacheSpark, #ApacheKafka &amp; #startups https://t.co/bXkKYi\u2026",
#   u'http://ln.is/paper.li/ThoHeller/Fzyna'),
#  (680728750955208704,
#   u'Sat Dec 26 12:35:56 +0000 2015',
#   2704548373,
#   u'NoSQL',
#   u"RT @ThoHeller: Natural Born Developer's Daily on #Containers, #Docker, #BigData, #ApacheSpark, #ApacheKafka &amp; #startups https://t.co/bXkKYi\u2026",
#   u'http://ln.is/paper.li/ThoHeller/Fzyna'),
#  (680722371255382016,
#   u'Sat Dec 26 12:10:35 +0000 2015',
#   3356052532,
#   u'Big Data Tweet',
#   u"RT @ThoHeller: Natural Born Developer's Daily on #Containers, #Docker, #BigData, #ApacheSpark, #ApacheKafka &amp; #startups https://t.co/bXkKYi\u2026",
#   u'http://ln.is/paper.li/ThoHeller/Fzyna'),
#  (680719847966289920,
#   u'Sat Dec 26 12:00:33 +0000 2015',
#   1499201215,
#   u'Tho Heller',
#   u"Natural Born Developer's Daily on #Containers, #Docker, #BigData, #ApacheSpark, #ApacheKafka &amp; #startups https://t.co/bXkKYixohX\n#ThoHeller",
#   u'http://ln.is/paper.li/ThoHeller/Fzyna'),
#  (680708439417434112,
#   u'Sat Dec 26 11:15:13 +0000 2015',
#   3391723768,
#   u'Christine',
#   u'RT @EmiliePeloille: Smart #weather #app #Apachespark @ErivoalPro @social_Kry @Ferreir_Cha  https://t.co/mOlC1qeJi8',
#   u'https://twitter.com/IBMbigdata/status/680448369857314820')]
